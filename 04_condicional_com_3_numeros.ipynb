# %% [markdown]
# <a href="https://colab.research.google.com/github/Larabeatrizsz/20241-algoritimos-estruturas-dados-larasimoes/blob/main/04_condicional_com_3_numeros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crie um código que, a partir de 3 variáveis
#'a','b' e 'c' númericas imprimar a maior delas
a=10
b=20
c=30

if a < b:
  if b < c:
    print(c)
  else:
    print(b)
else:
  if a < c:
    print(c)
  else:
    print(a)

# %%
#Simplificando com funções do python
a=10
b=20
c=30
d=40
e=50

print(max(a,b,c,d,e))
