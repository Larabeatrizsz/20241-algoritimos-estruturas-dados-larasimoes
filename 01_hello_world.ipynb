# %% [markdown]
# <a href="https://colab.research.google.com/github/Larabeatrizsz/20241-algoritimos-estruturas-dados-larasimoes/blob/main/01_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imprime "Hello, World" na tela
print("Hello, World")

# %%
#Variáveis em Python

#Atribui a string "Hello, World" a variável message
message = "Hello, World!"
#Imprimir o conteúdo da variável message
print(message)

# %%
#Entrada de dados do usuário
#Solicitar ao usuário que insira seu nome
nome = input("Qual o seu nome?")
print("Olá, " + nome + "!")
